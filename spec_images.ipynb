# %%
import pandas as pd
import numpy as np
import requests, json
import sys
import os

client_id = os.environ['BNET_CLIENT_ID']
client_secret = os.environ['BNET_SECRET']

def create_access_token(client_id, client_secret, region = 'us'):
    data = { 'grant_type': 'client_credentials' }
    response = requests.post('https://%s.battle.net/oauth/token' % region, data=data, auth=(client_id, client_secret))
    return response.json()

token = create_access_token(client_id, client_secret)['access_token']
#print(token)

# Get Specializations Index
spec_index = requests.get(f'https://us.api.blizzard.com/data/wow/playable-specialization/index?namespace=static-us&locale=en_US&access_token={token}').json()

spec_dict = {}

for i in spec_index['character_specializations']:
    spec_dict[i['id']] = {'spec_name':i['name']}

spec_df = pd.DataFrame.from_dict(spec_dict, orient='index')
spec_df.index.name = 'id'

# Add Class Name

class_id_dict = {}
for i in spec_df.index:
    spec_class = requests.get(f'https://us.api.blizzard.com/data/wow/playable-specialization/{i}?namespace=static-us&locale=en_US&access_token={token}').json()
    class_id_dict[i] = {'class_name':spec_class['playable_class']['name']}

class_id_df = pd.DataFrame.from_dict(class_id_dict, orient='index')
class_id_df.index.name = 'id'

spec_df = spec_df.join(class_id_df)

# Add Spec Media
spec_media_dict = {}

for i in spec_df.index:
    spec_media = requests.get(f'https://us.api.blizzard.com/data/wow/media/playable-specialization/{i}?namespace=static-us&locale=en_US&access_token={token}').json()
    spec_media_dict[i] = {'spec_media':spec_media['assets'][0]['value']}

spec_media_df = pd.DataFrame.from_dict(spec_media_dict, orient='index')
spec_media_df.index.name = 'id'

spec_df = spec_df.join(spec_media_df)

# Spec Colour Schemes
spec_colours = {'Monk':['#00FF98','#6effae','#9cffc2']}



spec_df.to_csv('spec_df.csv')

spec_df
# Out:
#           spec_name    class_name  \
# id
# 62           Arcane          Mage
# 63             Fire          Mage
# 64            Frost          Mage
# 65             Holy       Paladin
# 66       Protection       Paladin
# 70      Retribution       Paladin
# 71             Arms       Warrior
# 72             Fury       Warrior
# 73       Protection       Warrior
# 102         Balance         Druid
# 103           Feral         Druid
# 104        Guardian         Druid
# 105     Restoration         Druid
# 250           Blood  Death Knight
# 251           Frost  Death Knight
# 252          Unholy  Death Knight
# 253   Beast Mastery        Hunter
# 254    Marksmanship        Hunter
# 255        Survival        Hunter
# 256      Discipline        Priest
# 257            Holy        Priest
# 258          Shadow        Priest
# 259   Assassination         Rogue
# 260          Outlaw         Rogue
# 261        Subtlety         Rogue
# 262       Elemental        Shaman
# 263     Enhancement        Shaman
# 264     Restoration        Shaman
# 265      Affliction       Warlock
# 266      Demonology       Warlock
# 267     Destruction       Warlock
# 268      Brewmaster          Monk
# 269      Windwalker          Monk
# 270      Mistweaver          Monk
# 577           Havoc  Demon Hunter
# 581       Vengeance  Demon Hunter
# 1467    Devastation        Evoker
# 1468   Preservation        Evoker
# 1473   Augmentation        Evoker
#
#                                              spec_media
# id
# 62    https://render.worldofwarcraft.com/us/icons/56...
# 63    https://render.worldofwarcraft.com/us/icons/56...
# 64    https://render.worldofwarcraft.com/us/icons/56...
# 65    https://render.worldofwarcraft.com/us/icons/56...
# 66    https://render.worldofwarcraft.com/us/icons/56...
# 70    https://render.worldofwarcraft.com/us/icons/56...
# 71    https://render.worldofwarcraft.com/us/icons/56...
# 72    https://render.worldofwarcraft.com/us/icons/56...
# 73    https://render.worldofwarcraft.com/us/icons/56...
# 102   https://render.worldofwarcraft.com/us/icons/56...
# 103   https://render.worldofwarcraft.com/us/icons/56...
# 104   https://render.worldofwarcraft.com/us/icons/56...
# 105   https://render.worldofwarcraft.com/us/icons/56...
# 250   https://render.worldofwarcraft.com/us/icons/56...
# 251   https://render.worldofwarcraft.com/us/icons/56...
# 252   https://render.worldofwarcraft.com/us/icons/56...
# 253   https://render.worldofwarcraft.com/us/icons/56...
# 254   https://render.worldofwarcraft.com/us/icons/56...
# 255   https://render.worldofwarcraft.com/us/icons/56...
# 256   https://render.worldofwarcraft.com/us/icons/56...
# 257   https://render.worldofwarcraft.com/us/icons/56...
# 258   https://render.worldofwarcraft.com/us/icons/56...
# 259   https://render.worldofwarcraft.com/us/icons/56...
# 260   https://render.worldofwarcraft.com/us/icons/56...
# 261   https://render.worldofwarcraft.com/us/icons/56...
# 262   https://render.worldofwarcraft.com/us/icons/56...
# 263   https://render.worldofwarcraft.com/us/icons/56...
# 264   https://render.worldofwarcraft.com/us/icons/56...
# 265   https://render.worldofwarcraft.com/us/icons/56...
# 266   https://render.worldofwarcraft.com/us/icons/56...
# 267   https://render.worldofwarcraft.com/us/icons/56...
# 268   https://render.worldofwarcraft.com/us/icons/56...
# 269   https://render.worldofwarcraft.com/us/icons/56...
# 270   https://render.worldofwarcraft.com/us/icons/56...
# 577   https://render.worldofwarcraft.com/us/icons/56...
# 581   https://render.worldofwarcraft.com/us/icons/56...
# 1467  https://render.worldofwarcraft.com/us/icons/56...
# 1468  https://render.worldofwarcraft.com/us/icons/56...
# 1473  https://render.worldofwarcraft.com/us/icons/56...
